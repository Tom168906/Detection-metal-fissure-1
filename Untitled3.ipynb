# %% [markdown]
# <a href="https://colab.research.google.com/github/Tom168906/Detection-metal-fissure-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install inference-sdk pillow

# %%
from inference_sdk import InferenceHTTPClient

client = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="0ni1aLOl4URBmjk08gjY"
)

print("Client initialisé ✔")

from google.colab import files
uploaded = files.upload()
import os
print(os.listdir())

result = client.infer("image.jpg", model_id="my-first-project-utgik/1")
print(result)

from utils import draw_boxes

boxes = result.get("predictions", [])

# Format conversion : Roboflow donne des (x,y,w,h)
converted_boxes = []
for p in boxes:
    x, y, w, h = p["x"], p["y"], p["width"], p["height"]
    x1 = x - w/2
    y1 = y - h/2
    x2 = x + w/2
    y2 = y + h/2
    converted_boxes.append([x1, y1, x2, y2])

draw_boxes("image.jpg", converted_boxes, "output.jpg")

from IPython.display import Image
Image("output.jpg")
# Out:
# Client initialisé ✔
#      <input type="file" id="files-174804a7-9dd1-48c3-ab96-333b2d511034" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-174804a7-9dd1-48c3-ab96-333b2d511034">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
